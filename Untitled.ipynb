# %%
import pandas as pd

# %% [markdown]
# # Этап 1. Исследование данных (EDA)

# %% [markdown]
# ## 1.1 Знакомство с данными

# %%
df = pd.read_csv('real_estate_data.csv')
# Out:
# /tmp/ipykernel_9355/2314456965.py:1: DtypeWarning: Columns (0: floor_no, 1: heating_type) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('real_estate_data.csv')

# %%
df.size
# Out:
# 6859279

# %%
df.shape
# Out:
# (403487, 17)
